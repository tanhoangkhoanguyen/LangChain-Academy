# %% [markdown]
# ## **Online Evaluations**
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
from dotenv import load_dotenv, find_dotenv

_ = load_dotenv(find_dotenv())

# %% [markdown]
# ### **Running your Application**

# %%
from app import langsmith_rag

question = "How do I set up tracing to LangSmith with @traceable?"
langsmith_rag(question)
# Out:
# USER_AGENT environment variable not set, consider setting it to identify your requests.
# "To set up tracing to LangSmith using the @traceable decorator in Python, first, configure your environment by setting the `LANGSMITH_TRACING` environment variable to 'true' and the `LANGSMITH_API_KEY` to your API key. Then, simply decorate any function you want to trace with `@traceable`. Ensure that you have installed the necessary libraries and have the appropriate API keys set up as described in the context."
